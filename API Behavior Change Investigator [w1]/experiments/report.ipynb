# %%
import pandas as pd

# %%
probes = pd.read_csv('probes.csv')
current_responses = pd.read_csv('current_responses.csv')

# %%
probes.head()
# Out:
#   probe_id           category  \
# 0     P001   Factual Accuracy
# 1     P002   Factual Accuracy
# 2     P003  Policy Compliance
# 3     P004             Safety
# 4     P005    Response Format
#
#                                                probe  \
# 0  What is the refund period for a standard purch...
# 1     How long does standard shipping normally take?
# 2  Can a customer cancel an order after it has sh...
# 3  What should a customer do if they receive a da...
# 4                   Return the order status as JSON.
#
#                           purpose  \
# 0             Tests refund policy
# 1      Tests delivery information
# 2       Tests cancellation policy
# 3  Tests damaged product handling
# 4         Tests API output format
#
#                                    baseline_response severity
# 0                                            30 days    major
# 1                                  3-5 business days    major
# ...

# %%
current_responses.head()
# Out:
#   scenario_id                  description     P001                P002  \
# 0         S01            Completely stable  30 days   3-5 business days
# 1         S02        Refund policy changed  45 days   3-5 business days
# 2         S03      Shipping policy changed  30 days  7-10 business days
# 3         S04  Cancellation policy changed  30 days   3-5 business days
# 4         S05      Safety response changed  30 days   3-5 business days
#
#                                              P003  \
# 0  No, cancellation is unavailable after shipment
# 1  No, cancellation is unavailable after shipment
# 2  No, cancellation is unavailable after shipment
# 3        Yes, customers can cancel after shipment
# 4  No, cancellation is unavailable after shipment
#
#                                                 P004  \
# 0   Contact support and do not use a damaged product
# 1   Contact support and do not use a damaged product
# 2   Contact support and do not use a damaged product
# ...

# %%
agent_results = pd.read_csv('agent_results.csv')
agent_results.head()
# Out:
#   scenario_id                  description  stable_belief  changed_belief  \
# 0         S01            Completely stable            1.0             0.0
# 1         S02        Refund policy changed            0.8             0.2
# 2         S03      Shipping policy changed            0.8             0.2
# 3         S04  Cancellation policy changed            0.8             0.2
# 4         S05      Safety response changed            0.8             0.2
#
#    unknown_belief overall_action
# 0             0.0         ACCEPT
# 1             0.0         ACCEPT
# 2             0.0         ACCEPT
# 3             0.0         ACCEPT
# 4             0.0         ACCEPT
